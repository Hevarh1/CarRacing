# %%
# !sudo -H pip install gym
# !sudo -H pip install Box2D
# !sudo -H pip install gym[atari]
# !pip3 install -U 'mujoco-py<2.2,>=2.1'
# !sudo -H pip install pybullet
# !sudo apt install cmake swig zlib1g-dev python3-tk -y
# !sudo apt install ffmpeg
# !git clone https://github.com/Narsil/rl-baselines.git
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 2.4 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 205 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 90.8 MB 267 bytes/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# python3-tk is already the newest version (3.6.9-1~18.04).
# The following additional packages will be installed:
#   swig3.0
# Suggested packages:
#   swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig swig3.0
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,100 kB of archives.
# After this operation, 5,822 kB of additional disk space will be used.
# ...

# %%
cd rl-baselines/
# Out:
# /content/rl-baselines

# %%
# !git clone https://github.com/openai/gym
# !cd gym
# !pip3 install gym[all]
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb x11-utils
# !pip install gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.*
# !pip install pyvirtualdisplay
# !sudo apt-get install xvfb
# !pip install cma
# Out:
# Cloning into 'gym'...
# remote: Enumerating objects: 13032, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 13032 (delta 11), reused 7 (delta 3), pack-reused 12989
# Receiving objects: 100% (13032/13032), 5.35 MiB | 18.14 MiB/s, done.
# Resolving deltas: 100% (8881/8881), done.
# ...
#      |████████████████████████████████| 120 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 448 kB 48.5 MB/s
# ...
#   ERROR: Failed building wheel for mujoco-py
#   Running setup.py clean for mujoco-py
# Failed to build mujoco-py
# ...
#   Attempting uninstall: mujoco-py
#     Found existing installation: mujoco-py 2.1.2.14
#     Uninstalling mujoco-py-2.1.2.14:
#       Successfully uninstalled mujoco-py-2.1.2.14
#     Running setup.py install for mujoco-py ... error
#   Rolling back uninstall of mujoco-py
#   Moving to /usr/local/lib/python3.7/dist-packages/mujoco_py-2.1.2.14.dist-info/
# ...

# %%
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
_ = _display.start()

# !python -m rl_baselines.rcrc --env CarRacing-v0
# Out:
# 2022-01-21 15:18:47,534 - rcrc.py:212 - INFO - Using RCRC formulation.
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (1,2mirr1)-aCMA-ES (mu_w=1.0,w_1=100%) in dimension 4995 (seed=801114, Fri Jan 21 15:18:48 2022)
# 2022-01-21 15:18:51,432 - rcrc.py:151 - DEBUG - Attempting to solve CarRacing-v0
# 2022-01-21 15:18:51,432 - rcrc.py:152 - DEBUG - Epochs: 2
# 2022-01-21 15:18:51,432 - rcrc.py:153 - DEBUG - Episodes per update: 4
# 2022-01-21 15:18:51,432 - rcrc.py:154 - DEBUG - Policy Update: RCRCUpdate(
#   (model): FixedRandomModel(
#     (conv): Conv(
#       (conv1): Conv2d(3, 32, kernel_size=(31, 31), stride=(2, 2))
# ...

# %%
# !python -m rl_baselines.test_agent --model=/content/rl-baselines/runs/Jan21_15-18-47/checkpoint.pth --env=CarRacing-v0
# Out:
# 2022-01-21 15:24:58,326 - test_agent.py:11 - DEBUG - Loaded : RCRCUpdate(
#   (model): FixedRandomModel(
#     (conv): Conv(
#       (conv1): Conv2d(3, 32, kernel_size=(31, 31), stride=(2, 2))
#       (conv2): Conv2d(32, 64, kernel_size=(14, 14), stride=(2, 2))
#       (conv3): Conv2d(64, 128, kernel_size=(6, 6), stride=(2, 2))
#     )
#     (W_in): Linear(in_features=1152, out_features=512, bias=False)
#     (W): Linear(in_features=512, out_features=512, bias=False)
#   )
# )
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Track generation: 919..1156 -> 237-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 985..1238 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1092..1369 -> 277-tiles track
# ...
